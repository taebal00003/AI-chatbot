# %%
# !pip install -U langchain-chroma
# Out:
# Requirement already satisfied: langchain-chroma in C:\RAG\venv\Lib\site-packages (1.1.0)
# Requirement already satisfied: chromadb<2.0.0,>=1.3.5 in C:\RAG\venv\Lib\site-packages (from langchain-chroma) (1.5.7)
# Requirement already satisfied: langchain-core<2.0.0,>=1.1.3 in C:\RAG\venv\Lib\site-packages (from langchain-chroma) (1.2.20)
# Requirement already satisfied: numpy>=2.1.0 in C:\RAG\venv\Lib\site-packages (from langchain-chroma) (2.4.3)
# Requirement already satisfied: build>=1.0.3 in C:\RAG\venv\Lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.4.3)
# Requirement already satisfied: pydantic>=2.0 in C:\RAG\venv\Lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.12.5)
# Requirement already satisfied: pydantic-settings>=2.0 in C:\RAG\venv\Lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.13.1)
# Requirement already satisfied: pybase64>=1.4.1 in C:\RAG\venv\Lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in C:\RAG\venv\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.44.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in C:\RAG\venv\Lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (4.15.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in C:\RAG\venv\Lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.24.4)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in C:\RAG\venv\Lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.41.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in C:\RAG\venv\Lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.41.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in C:\RAG\venv\Lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.41.0)
# Requirement already satisfied: tokenizers>=0.13.2 in C:\RAG\venv\Lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.22.2)
# Requirement already satisfied: pypika>=0.48.9 in C:\RAG\venv\Lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.51.1)
# Requirement already satisfied: tqdm>=4.65.0 in C:\RAG\venv\Lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (4.67.3)
# Requirement already satisfied: overrides>=7.3.1 in C:\RAG\venv\Lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (7.7.0)
# Requirement already satisfied: importlib-resources in C:\RAG\venv\Lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (7.1.0)
# Requirement already satisfied: grpcio>=1.58.0 in C:\RAG\venv\Lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.80.0)
# Requirement already satisfied: bcrypt>=4.0.1 in C:\RAG\venv\Lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in C:\RAG\venv\Lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.24.1)
# Requirement already satisfied: kubernetes>=28.1.0 in C:\RAG\venv\Lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (35.0.0)
# Requirement already satisfied: tenacity>=8.2.3 in C:\RAG\venv\Lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (9.1.4)
# Requirement already satisfied: pyyaml>=6.0.0 in C:\RAG\venv\Lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (6.0.3)
# Requirement already satisfied: mmh3>=4.0.1 in C:\RAG\venv\Lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (5.2.1)
# Requirement already satisfied: orjson>=3.9.12 in C:\RAG\venv\Lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (3.11.7)
# Requirement already satisfied: httpx>=0.27.0 in C:\RAG\venv\Lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in C:\RAG\venv\Lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (15.0.0)
# Requirement already satisfied: jsonschema>=4.19.0 in C:\RAG\venv\Lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (4.26.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in C:\RAG\venv\Lib\site-packages (from langchain-core<2.0.0,>=1.1.3->langchain-chroma) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in C:\RAG\venv\Lib\site-packages (from langchain-core<2.0.0,>=1.1.3->langchain-chroma) (0.7.16)
# Requirement already satisfied: packaging>=23.2.0 in C:\RAG\venv\Lib\site-packages (from langchain-core<2.0.0,>=1.1.3->langchain-chroma) (26.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in C:\RAG\venv\Lib\site-packages (from langchain-core<2.0.0,>=1.1.3->langchain-chroma) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in C:\RAG\venv\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (3.0.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in C:\RAG\venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in C:\RAG\venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (2.32.5)
# Requirement already satisfied: xxhash>=3.0.0 in C:\RAG\venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in C:\RAG\venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (0.25.0)
# Requirement already satisfied: anyio in C:\RAG\venv\Lib\site-packages (from httpx>=0.27.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (4.12.1)
# Requirement already satisfied: certifi in C:\RAG\venv\Lib\site-packages (from httpx>=0.27.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in C:\RAG\venv\Lib\site-packages (from httpx>=0.27.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.0.9)
# Requirement already satisfied: idna in C:\RAG\venv\Lib\site-packages (from httpx>=0.27.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (3.11)
# Requirement already satisfied: h11>=0.16 in C:\RAG\venv\Lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\RAG\venv\Lib\site-packages (from pydantic>=2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in C:\RAG\venv\Lib\site-packages (from pydantic>=2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\RAG\venv\Lib\site-packages (from pydantic>=2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.4.2)
# Requirement already satisfied: pyproject_hooks in C:\RAG\venv\Lib\site-packages (from build>=1.0.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.2.0)
# Requirement already satisfied: colorama in C:\RAG\venv\Lib\site-packages (from build>=1.0.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.4.6)
# Requirement already satisfied: attrs>=22.2.0 in C:\RAG\venv\Lib\site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in C:\RAG\venv\Lib\site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in C:\RAG\venv\Lib\site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in C:\RAG\venv\Lib\site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.30.0)
# Requirement already satisfied: six>=1.9.0 in C:\RAG\venv\Lib\site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in C:\RAG\venv\Lib\site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in C:\RAG\venv\Lib\site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.9.0)
# Requirement already satisfied: requests-oauthlib in C:\RAG\venv\Lib\site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.0.0)
# Requirement already satisfied: urllib3!=2.6.0,>=1.24.2 in C:\RAG\venv\Lib\site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.6.3)
# Requirement already satisfied: durationpy>=0.7 in C:\RAG\venv\Lib\site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.10)
# Requirement already satisfied: flatbuffers in C:\RAG\venv\Lib\site-packages (from onnxruntime>=1.14.1->chromadb<2.0.0,>=1.3.5->langchain-chroma) (25.12.19)
# Requirement already satisfied: protobuf in C:\RAG\venv\Lib\site-packages (from onnxruntime>=1.14.1->chromadb<2.0.0,>=1.3.5->langchain-chroma) (6.33.6)
# Requirement already satisfied: sympy in C:\RAG\venv\Lib\site-packages (from onnxruntime>=1.14.1->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in C:\RAG\venv\Lib\site-packages (from opentelemetry-api>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (8.7.1)
# Requirement already satisfied: zipp>=3.20 in C:\RAG\venv\Lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (3.23.1)
# Requirement already satisfied: googleapis-common-protos~=1.57 in C:\RAG\venv\Lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.74.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.41.0 in C:\RAG\venv\Lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.41.0)
# Requirement already satisfied: opentelemetry-proto==1.41.0 in C:\RAG\venv\Lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.41.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.62b0 in C:\RAG\venv\Lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.62b0)
# Requirement already satisfied: python-dotenv>=0.21.0 in C:\RAG\venv\Lib\site-packages (from pydantic-settings>=2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\RAG\venv\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (3.4.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\RAG\venv\Lib\site-packages (from rich>=10.11.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\RAG\venv\Lib\site-packages (from rich>=10.11.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in C:\RAG\venv\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.1.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in C:\RAG\venv\Lib\site-packages (from tokenizers>=0.13.2->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.10.2)
# Requirement already satisfied: filelock>=3.10.0 in C:\RAG\venv\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb<2.0.0,>=1.3.5->langchain-chroma) (3.28.0)
# Requirement already satisfied: fsspec>=2023.5.0 in C:\RAG\venv\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2026.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in C:\RAG\venv\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.4.3)
# Requirement already satisfied: click>=8.2.1 in C:\RAG\venv\Lib\site-packages (from typer>=0.9.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (8.3.2)
# Requirement already satisfied: shellingham>=1.3.0 in C:\RAG\venv\Lib\site-packages (from typer>=0.9.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in C:\RAG\venv\Lib\site-packages (from typer>=0.9.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.0.4)
# Requirement already satisfied: httptools>=0.6.3 in C:\RAG\venv\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.7.1)
# Requirement already satisfied: watchfiles>=0.20 in C:\RAG\venv\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in C:\RAG\venv\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (16.0)
# Requirement already satisfied: oauthlib>=3.0.0 in C:\RAG\venv\Lib\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in C:\RAG\venv\Lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.3.0)

# %%
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain_chroma import Chroma
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough, RunnableWithMessageHistory
from langchain_community.chat_message_histories import ChatMessageHistory


# PDF 문서 로드 및 텍스트 분할
loader = PyPDFLoader("2024_KB_부동산_보고서_최종.pdf")
documents = loader.load()  # 문서 로드

# 텍스트 분할 설정: 청크 크기와 겹침 설정
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
chunks = text_splitter.split_documents(documents)

# 분할된 청크 수
print('분할된 청크의 수:', len(chunks))
    
    
# 임베딩 생성 및 Chroma 데이터베이스 저장
embedding_function = OpenAIEmbeddings()  # 임베딩 모델 설정

persist_directory = "/content/drive/MyDrive/langchain-tutorial/Ch02. RAG/directory/chroma"

vectorstore = Chroma.from_documents(
    documents=chunks,
    embedding=embedding_function,
    persist_directory=persist_directory  # 데이터베이스 저장 경로
)

print('문서의 수:', vectorstore._collection.count())
# Out:
# 분할된 청크의 수: 135
# 문서의 수: 135

# %%
# 검색 및 재정렬
retriever = vectorstore.as_retriever(search_kwargs={"k": 3})  # 관련 문서 상위 3개 검색 설정

# 프롬프트 템플릿 설정: 사용자 질문에 대한 답변을 생성하기 위한 템플릿
template = """당신은 KB 부동산 보고서 전문가입니다. 다음 정보를 바탕으로 사용자의 질문에 답변해주세요.

컨텍스트: {context}
"""
prompt = ChatPromptTemplate.from_messages(
    [
        ("system", template),
        ("placeholder", "{chat_history}"),
        ("human", "{question}")
    ]
)  # 템플릿 초기화
model = ChatOpenAI(model_name="gpt-4o-mini", temperature=0)  # AI 모델 설정
     

print(prompt.format(context="컨텍스트 예시", chat_history=["대화 기록 예시1", "대화 기록 예시2"], question="질문 예시"))
# Out:
# System: 당신은 KB 부동산 보고서 전문가입니다. 다음 정보를 바탕으로 사용자의 질문에 답변해주세요.
#
# 컨텍스트: 컨텍스트 예시
#
# Human: 대화 기록 예시1
# Human: 대화 기록 예시2
# Human: 질문 예시

# %%
def format_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs)  # 문서 내용을 줄바꿈으로 연결
# 체인 구성: 검색한 문서를 프롬프트에 연결하고 모델을 통해 응답 생성
chain = (
    RunnablePassthrough.assign(
        context=lambda x: format_docs(retriever.invoke(x["question"]))
    )  # 검색된 문서를 연결하여 전달
    | prompt
    | model
    | StrOutputParser()  # 결과를 문자열로 변환
)

# %%
# 대화 기록을 유지하기 위한 메모리 설정
chat_history = ChatMessageHistory()
chain_with_memory = RunnableWithMessageHistory(
    chain,
    lambda session_id: chat_history,  # 세션 ID별 대화 기록 생성
    input_messages_key="question",
    history_messages_key="chat_history",
)

# %%
# 챗봇 실행 함수 정의
def chat_with_bot():
    session_id = "user_session"
    print("KB 부동산 보고서 챗봇입니다. 질문해 주세요. (종료하려면 'quit' 입력)")
    while True:
        user_input = input("사용자: ")
        if user_input.lower() == 'quit':
            break

        response = chain_with_memory.invoke(
            {"question": user_input},
            {"configurable": {"session_id": session_id}}
        )

        print("챗봇:", response)

# 메인 실행
if __name__ == "__main__":
    chat_with_bot()
# Out:
# KB 부동산 보고서 챗봇입니다. 질문해 주세요. (종료하려면 'quit' 입력)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 19
#      17 # 메인 실행
#      18 if __name__ == "__main__":
# ---> 19     chat_with_bot()
#
# Cell In[6], line 6, in chat_with_bot()
#       4 print("KB 부동산 보고서 챗봇입니다. 질문해 주세요. (종료하려면 'quit' 입력)")
#       5 while True:
# ----> 6     user_input = input("사용자: ")
#       7     if user_input.lower() == 'quit':
#       8         break
#
# File c:\RAG\venv\Lib\site-packages\ipykernel\kernelbase.py:1403, in Kernel.raw_input(self, prompt)
#    1401     msg = "raw_input was called, but this frontend does not support input requests."
#    1402     raise StdinNotImplementedError(msg)
# -> 1403 return self._input_request(
#    1404     str(prompt),
#    1405     self._get_shell_context_var(self._shell_parent_ident),
#    1406     self.get_parent("shell"),
#    1407     password=False,
#    1408 )
#
# File c:\RAG\venv\Lib\site-packages\ipykernel\kernelbase.py:1448, in Kernel._input_request(self, prompt, ident, parent, password)
#    1445 except KeyboardInterrupt:
#    1446     # re-raise KeyboardInterrupt, to truncate traceback
#    1447     msg = "Interrupted by user"
# -> 1448     raise KeyboardInterrupt(msg) from None
#    1449 except Exception:
#    1450     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
# !ngrok config add-authtoken 3CQBplZ9iPEE1RRPYjm1j5IX8vb_KK3ZABBxbvpZNJ6Jdmk6
# Out:
# Authtoken saved to configuration file: C:\Users\SAMSUNG\AppData\Local\ngrok\ngrok.yml

# %%
from pyngrok import ngrok

public_url = ngrok.connect(8501)  # Streamlit 기본 포트
print("앱 접속 URL:", public_url)
# !streamlit run app_test.py
# Out:
# 앱 접속 URL: NgrokTunnel: "https://mooned-purveyor-verbalize.ngrok-free.dev" -> "http://localhost:8501"
